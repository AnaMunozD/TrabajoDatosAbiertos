# %%
import pandas as pd

url = '/Precio_m_ximo_de_venta_de_los_medicamentos_por_presentaci_n_comercial_20240413.csv'
df = pd.read_csv(url)

#mostrar las primeras filas
#print(df.head())

#calcular estadistica descriptiva
#print(df.describe())

#filtrar datos
filtro = df['Descripción Principio Activo'] == 'Linezolid'
datosfiltrados = df[filtro]
print(datosfiltrados)

columnas = df.columns
print(columnas)

#revisar cantidad de columnas y filas
shape = df.shape
print(shape)

#mostrar los ultimos datos del df
tail = df.tail
print(tail)

#valores unicos
unique = df['Forma Farmacéutica'].unique()
print(unique)

#contar valores
count_unique_values = df['Forma Farmacéutica'].value_counts()
print(count_unique_values)

#estadistica
print(df['No.'].mean())

#resumen del df
print(df.info())

#ver elementos aleatorios
print(df.sample(5))

#construir un df del df
df[['Forma Farmacéutica', 'Medicamento']]

#crear una nueva columna
df['new'] = df['No.'] * 4
print(df)
df.drop('new', axis = 'columns')


#eliminar filas o columnas puede ser por valores nulos
df.drop(1, axis= 'index')
# Out:
#          No.      ATC ID MR Descripción Principio Activo Forma Farmacéutica  \
# 170      171  J01XX08    49                    Linezolid      Sólido - Oral
# 171      172  J01XX08    49                    Linezolid      Sólido - Oral
# 172      173  J01XX08    49                    Linezolid      Sólido - Oral
# 173      174  J01XX08    49                    Linezolid      Sólido - Oral
# 174      175  J01XX08    49                    Linezolid      Sólido - Oral
# ...      ...      ...   ...                          ...                ...
# 52406  22666  J01XX08    49                    Linezolid      Sólido - Oral
# 52407  22667  J01XX08    49                    Linezolid      Sólido - Oral
# 58515  28862  J01XX08    49                    Linezolid      Sólido - Oral
# 58565  28861  J01XX08    49                    Linezolid      Sólido - Oral
# 58566  28863  J01XX08    49                    Linezolid      Sólido - Oral
#
# ...
